# %%
import pandas as pd
from pandas import datetime
import matplotlib.pyplot as plt

# %%
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
df = pd.read_csv("input.csv", parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
df.head()
# Out:
# Month
# 1901-01-01    266.0
# 1901-02-01    145.9
# 1901-03-01    183.1
# 1901-04-01    119.3
# 1901-05-01    180.3
# Name: Sales of shampoo over a three year period, dtype: float64

# %%
df.plot()
plt.show()

# %%
X = df.values
test, train = X[-12:], X[:-12]
print(len(test), len(train))
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    predictions.append(history[-1])
    history.append(test[i])
plt.plot(test)
plt.plot(predictions)
plt.show()
# Out:
# 12 23
